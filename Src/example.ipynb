# %%
'''
Elliptic Curve defined by y^2*z + 8*x*y*z + y*z^2 = x^3 + 10*x^2*z + x*z^2 + 3*z^3 over local ring Ring of integers modulo 14641 with Principal ideal (11) of Ring of integers modulo 14641 as the maximal ideal
(6 : 3 : 1)
Ring of integers modulo 14641
Principal ideal (11) of Ring of integers modulo 14641
s=1683
ts=[]
'''
# Out:
# '\nElliptic Curve defined by y^2*z + 8*x*y*z + y*z^2 = x^3 + 10*x^2*z + x*z^2 + 3*z^3 over local ring Ring of integers modulo 14641 with Principal ideal (11) of Ring of integers modulo 14641 as the maximal ideal\n(6 : 3 : 1)\nRing of integers modulo 14641\nPrincipal ideal (11) of Ring of integers modulo 14641\ns=1683\nts=[]\n'

# %%
11^4
# Out:
# 14641

# %%
R = Zmod(14641)

# %%
I = R.ideal(11)

# %%
1683 in I
# Out:
# True

# %%
E = EllipticCurve(Zmod(11),[8,10,1,1,3])

# %%
E(6,3,1)
# Out:
# (6 : 3 : 1)

# %%
x = R(6 + 1683)
y = R(3)
z = R(1)
[t for t in R if (y+t)^2*z + R(8)*x*(y+t)*z + (y+t)*z^2 == x^3 + R(10)*x^2*z + x*z^2 + R(3)*z^3]
# Out:
# []

# %%
2*3 + 8*6 + 1
# Out:
# 55

# %%
x
# Out:
# 1689

# %%
x = 1689
y = 3
z = 1
for i in range(14641):
    if mod((y+i)^2*z + 8*x*(y+i)*z + (y+i)*z^2 - ( x^3 + 10*x^2*z + x*z^2 + 3*z^3),11^4) == 0:
        print(i)

# %%
x = 6
y = 3
z = 1
mod(y^2*z + 8*x*y*z + y*z^2,11) == mod(x^3 + 10*x^2*z + x*z^2 + 3*z^3,11)
# Out:
# True

# %%
2*y + 8*x + 1
# Out:
# 55

# %%
'''
Elliptic Curve defined by y^2*z + 8*x*y*z + y*z^2 = x^3 + 10*x^2*z + x*z^2 + 3*z^3 over local ring Ring of integers modulo 14641 with Principal ideal (11) of Ring of integers modulo 14641 as the maximal ideal
(6 : 3 : 1)
Ring of integers modulo 14641
Principal ideal (11) of Ring of integers modulo 14641
s=1683
ts=[]
Elliptic Curve defined by y^2*z + 12*x*y*z + 12*y*z^2 = x^3 + 12*x^2*z + 8*x*z^2 + 3*z^3 over local ring Ring of integers modulo 83521 with Principal ideal (17) of Ring of integers modulo 83521 as the maximal ideal
(11 : 13 : 1)
Ring of integers modulo 83521
Principal ideal (17) of Ring of integers modulo 83521
s=62696
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(1 : 2 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=230
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(4 : 0 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=575
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(3 : 4 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=160
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(3 : 4 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=600
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(3 : 4 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=575
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(1 : 2 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=510
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=560
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(4 : 0 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=430
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=400
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=270
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(1 : 2 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=440
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(4 : 0 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=540
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=300
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(1 : 2 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=55
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(1 : 2 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=480
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=365
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=275
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(4 : 0 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=250
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=295
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=400
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(4 : 0 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=405
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(3 : 4 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=605
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=375
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(1 : 2 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=215
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(4 : 0 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=425
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(3 : 4 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=325
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(3 : 4 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=80
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(4 : 0 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=200
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(4 : 0 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=120
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(3 : 4 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=605
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(4 : 0 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=30
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=310
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=580
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(4 : 0 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=505
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=200
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(4 : 0 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=150
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + x^2*z + x*z^2 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 1 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=14
ts=[]
Elliptic Curve defined by y^2*z + y*z^2 = x^3 + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 81 with Principal ideal (3) of Ring of integers modulo 81 as the maximal ideal
(1 : 1 : 1)
Ring of integers modulo 81
Principal ideal (3) of Ring of integers modulo 81
s=0
ts=[]
Elliptic Curve defined by y^2*z + y*z^2 = x^3 + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 81 with Principal ideal (3) of Ring of integers modulo 81 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 81
Principal ideal (3) of Ring of integers modulo 81
s=57
ts=[]
Elliptic Curve defined by y^2*z + y*z^2 = x^3 + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 81 with Principal ideal (3) of Ring of integers modulo 81 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 81
Principal ideal (3) of Ring of integers modulo 81
s=36
ts=[]
Elliptic Curve defined by y^2*z + y*z^2 = x^3 + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 81 with Principal ideal (3) of Ring of integers modulo 81 as the maximal ideal
(0 : 1 : 1)
Ring of integers modulo 81
Principal ideal (3) of Ring of integers modulo 81
s=60
ts=[]
Elliptic Curve defined by y^2*z + y*z^2 = x^3 + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 81 with Principal ideal (3) of Ring of integers modulo 81 as the maximal ideal
(1 : 1 : 1)
Ring of integers modulo 81
Principal ideal (3) of Ring of integers modulo 81
s=78
ts=[]
Elliptic Curve defined by y^2*z + y*z^2 = x^3 + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 81 with Principal ideal (3) of Ring of integers modulo 81 as the maximal ideal
(1 : 1 : 1)
Ring of integers modulo 81
Principal ideal (3) of Ring of integers modulo 81
s=15
ts=[]
Elliptic Curve defined by y^2*z + y*z^2 = x^3 + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 81 with Principal ideal (3) of Ring of integers modulo 81 as the maximal ideal
(2 : 1 : 1)
Ring of integers modulo 81
Principal ideal (3) of Ring of integers modulo 81
s=27
ts=[]
Elliptic Curve defined by y^2*z + y*z^2 = x^3 + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 81 with Principal ideal (3) of Ring of integers modulo 81 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 81
Principal ideal (3) of Ring of integers modulo 81
s=33
ts=[]
Elliptic Curve defined by y^2*z + y*z^2 = x^3 + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 81 with Principal ideal (3) of Ring of integers modulo 81 as the maximal ideal
(0 : 1 : 1)
Ring of integers modulo 81
Principal ideal (3) of Ring of integers modulo 81
s=45
ts=[]
Elliptic Curve defined by y^2*z + y*z^2 = x^3 + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 81 with Principal ideal (3) of Ring of integers modulo 81 as the maximal ideal
(0 : 1 : 1)
Ring of integers modulo 81
Principal ideal (3) of Ring of integers modulo 81
s=45
ts=[]
Elliptic Curve defined by y^2*z + x*y*z = x^3 + x^2*z + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=6
ts=[]
Elliptic Curve defined by y^2*z + x*y*z = x^3 + x^2*z + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=14
ts=[]
Elliptic Curve defined by y^2*z + x*y*z = x^3 + x^2*z + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=10
ts=[]
Elliptic Curve defined by y^2*z + x*y*z = x^3 + x^2*z + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=4
ts=[]
Elliptic Curve defined by y^2*z + x*y*z = x^3 + x^2*z + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=4
ts=[]
Elliptic Curve defined by y^2*z + x*y*z = x^3 + x^2*z + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=4
ts=[]
Elliptic Curve defined by y^2*z + x*y*z = x^3 + x^2*z + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=14
ts=[]
Elliptic Curve defined by y^2*z + x*y*z = x^3 + x^2*z + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=6
ts=[]
Elliptic Curve defined by y^2*z + 2*x*y*z = x^3 + x^2*z + x*z^2 + 2*z^3 over local ring Ring of integers modulo 81 with Principal ideal (3) of Ring of integers modulo 81 as the maximal ideal
(1 : 2 : 1)
Ring of integers modulo 81
Principal ideal (3) of Ring of integers modulo 81
s=54
ts=[]
Elliptic Curve defined by y^2*z + 8*x*y*z + 5*y*z^2 = x^3 + 7*x^2*z + 5*x*z^2 + 12*z^3 over local ring Ring of integers modulo 28561 with Principal ideal (13) of Ring of integers modulo 28561 as the maximal ideal
(6 : 6 : 1)
Ring of integers modulo 28561
Principal ideal (13) of Ring of integers modulo 28561
s=12012
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + x*z^2 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 1 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=4
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + x*z^2 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=0
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + x*z^2 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 1 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=2
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + x*z^2 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=8
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + x*z^2 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=8
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + x*z^2 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=10
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + x*z^2 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=8
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + 7*y*z^2 = x^3 + 5*x^2*z + 9*x*z^2 + 7*z^3 over local ring Ring of integers modulo 14641 with Principal ideal (11) of Ring of integers modulo 14641 as the maximal ideal
(10 : 8 : 1)
Ring of integers modulo 14641
Principal ideal (11) of Ring of integers modulo 14641
s=4807
ts=[]
Elliptic Curve defined by y^2*z + y*z^2 = x^3 + 3*x^2*z + 2*x*z^2 + z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(4 : 2 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=255
ts=[]
Elliptic Curve defined by y^2*z + 3*x*y*z = x^3 + 6*x^2*z + 2*x*z^2 + z^3 over local ring Ring of integers modulo 2401 with Principal ideal (7) of Ring of integers modulo 2401 as the maximal ideal
(1 : 2 : 1)
Ring of integers modulo 2401
Principal ideal (7) of Ring of integers modulo 2401
s=651
ts=[]
Elliptic Curve defined by y^2*z + x*y*z = x^3 + x^2*z + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=2
ts=[]
Elliptic Curve defined by y^2*z + 2*x*y*z + 2*y*z^2 = x^3 + 4*x^2*z + 6*x*z^2 + 4*z^3 over local ring Ring of integers modulo 2401 with Principal ideal (7) of Ring of integers modulo 2401 as the maximal ideal
(2 : 4 : 1)
Ring of integers modulo 2401
Principal ideal (7) of Ring of integers modulo 2401
s=252
ts=[]
Elliptic Curve defined by y^2*z + 2*x*y*z + 2*y*z^2 = x^3 + 4*x^2*z + 6*x*z^2 + 4*z^3 over local ring Ring of integers modulo 2401 with Principal ideal (7) of Ring of integers modulo 2401 as the maximal ideal
(2 : 4 : 1)
Ring of integers modulo 2401
Principal ideal (7) of Ring of integers modulo 2401
s=2345
ts=[]
Elliptic Curve defined by y^2*z + 2*x*y*z + 2*y*z^2 = x^3 + 4*x^2*z + 6*x*z^2 + 4*z^3 over local ring Ring of integers modulo 2401 with Principal ideal (7) of Ring of integers modulo 2401 as the maximal ideal
(2 : 4 : 1)
Ring of integers modulo 2401
Principal ideal (7) of Ring of integers modulo 2401
s=2107
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + x*z^2 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 1 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=6
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + x*z^2 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=12
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + x*z^2 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=12
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + x*z^2 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=2
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + x*z^2 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 1 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=14
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + x*z^2 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 1 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=8
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + x*z^2 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 1 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=8
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + x*z^2 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=12
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + x*z^2 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 1 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=10
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 0 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=6
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=8
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 0 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=0
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 0 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=0
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=14
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 0 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=4
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 0 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=4
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=14
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=0
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=2
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=10
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=6
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 0 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=10
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 0 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=6
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=0
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=6
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 0 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=6
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 0 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=6
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=12
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 0 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=10
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 0 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=6
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 0 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=12
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=0
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 0 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=8
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 0 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=6
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 0 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=0
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(0 : 1 : 0)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=0
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + z^3 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 0 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=0
ts=[]
Elliptic Curve defined by y^2*z + 2*x*y*z + y*z^2 = x^3 + 2*x^2*z + z^3 over local ring Ring of integers modulo 81 with Principal ideal (3) of Ring of integers modulo 81 as the maximal ideal
(2 : 2 : 1)
Ring of integers modulo 81
Principal ideal (3) of Ring of integers modulo 81
s=72
ts=[]
Elliptic Curve defined by y^2*z + x*y*z + 8*y*z^2 = x^3 + 2*x^2*z + 2*x*z^2 + 5*z^3 over local ring Ring of integers modulo 14641 with Principal ideal (11) of Ring of integers modulo 14641 as the maximal ideal
(1 : 1 : 1)
Ring of integers modulo 14641
Principal ideal (11) of Ring of integers modulo 14641
s=1210
ts=[]
'''
# Out:
# '\nElliptic Curve defined by y^2*z + 8*x*y*z + y*z^2 = x^3 + 10*x^2*z + x*z^2 + 3*z^3 over local ring Ring of integers modulo 14641 with Principal ideal (11) of Ring of integers modulo 14641 as the maximal ideal\n(6 : 3 : 1)\nRing of integers modulo 14641\nPrincipal ideal (11) of Ring of integers modulo 14641\ns=1683\nts=[]\nElliptic Curve defined by y^2*z + 12*x*y*z + 12*y*z^2 = x^3 + 12*x^2*z + 8*x*z^2 + 3*z^3 over local ring Ring of integers modulo 83521 with Principal ideal (17) of Ring of integers modulo 83521 as the maximal ideal\n(11 : 13 : 1)\nRing of integers modulo 83521\nPrincipal ideal (17) of Ring of integers modulo 83521\ns=62696\nts=[]\nElliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal\n(1 : 2 : 1)\nRing of integers modulo 625\nPrincipal ideal (5) of Ring of integers modulo 625\ns=230\nts=[]\nElliptic Curve defined b
# ...

# %%
'''
K = GF(5)
Rx.<x> = PolynomialRing(K)
R.<e> = QuotientRing(Rx,Rx.ideal(x^3))
m = R.ideal(e)
E = MyEllipticCurve(R,[4,5],m = m)

s = e^2 + 2*e
P_below = (1 : 0 : 1)
'''
K = GF(5)
Rx.<x> = PolynomialRing(K)
R.<e> = QuotientRing(Rx,Rx.ideal(x^3))
m = R.ideal(e)
num=0
for i in range(5):
    for j in range(5):
        for k in range(5):
            x = R([1]) + R([i,j,k])
            y = R([0])
            z = R([1])
            ts = [R([t0,t1,t2]) for t0 in K for t1 in K for t2 in K if (R([t0,t1,t2]) + y)^2 == x^3 + R([4])*x+R([5])]
            if len(ts) != 0:
                print("s=%s" %(R([i,j,k])))
                print("ts = %s" %ts)
                print(len(ts))
            num = num + len(ts)
# Out:
# s=0
# ts = [0, e^2, 2*e^2, 3*e^2, 4*e^2]
# 5
# s=2*e^2
# ts = [2*e, e^2 + 2*e, 2*e^2 + 2*e, 3*e^2 + 2*e, 4*e^2 + 2*e, 3*e, e^2 + 3*e, 2*e^2 + 3*e, 3*e^2 + 3*e, 4*e^2 + 3*e]
# 10
# s=3*e^2
# ts = [e, e^2 + e, 2*e^2 + e, 3*e^2 + e, 4*e^2 + e, 4*e, e^2 + 4*e, 2*e^2 + 4*e, 3*e^2 + 4*e, 4*e^2 + 4*e]
# 10
# s=1
# ts = [1, 4]
# 2
# s=e^2 + 1
# ts = [3*e^2 + 1, 2*e^2 + 4]
# 2
# s=2*e^2 + 1
# ts = [e^2 + 1, 4*e^2 + 4]
# 2
# s=3*e^2 + 1
# ts = [4*e^2 + 1, e^2 + 4]
# 2
# s=4*e^2 + 1
# ts = [2*e^2 + 1, 3*e^2 + 4]
# 2
# s=e + 1
# ts = [e^2 + 3*e + 1, 4*e^2 + 2*e + 4]
# 2
# s=e^2 + e + 1
# ts = [4*e^2 + 3*e + 1, e^2 + 2*e + 4]
# 2
# s=2*e^2 + e + 1
# ts = [2*e^2 + 3*e + 1, 3*e^2 + 2*e + 4]
# 2
# s=3*e^2 + e + 1
# ts = [3*e + 1, 2*e + 4]
# 2
# s=4*e^2 + e + 1
# ts = [3*e^2 + 3*e + 1, 2*e^2 + 2*e + 4]
# 2
# s=2*e + 1
# ts = [4*e^2 + e + 1, e^2 + 4*e + 4]
# 2
# s=e^2 + 2*e + 1
# ts = [2*e^2 + e + 1, 3*e^2 + 4*e + 4]
# 2
# s=2*e^2 + 2*e + 1
# ts = [e + 1, 4*e + 4]
# 2
# s=3*e^2 + 2*e + 1
# ...

# %%
'''
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(1 : 2 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=230
ts=[]
'''
R = Zmod(625)
num = 0
for i in range(125):
    x = R(1 + i*5)
    y = R(2)
    z = R(1)
    ts = [t for t in R if (y+t)^2*z + R(3)*x*(y+t)*z + 3*(y+t)*z^2 == x^3 + R(1)*x^2*z + 2*x*z^2 + R(2)*z^3]
    if len(ts) != 0:
        print("s=%s" %(5*i))
        print("ts = %s" %ts)
        print(len(ts))
    num = num + len(ts)
# Out:
# s=60
# ts = [20, 40, 145, 165, 270, 290, 395, 415, 520, 540]
# 10
# s=110
# ts = [50, 110, 175, 235, 300, 360, 425, 485, 550, 610]
# 10
# s=185
# ts = [15, 45, 140, 170, 265, 295, 390, 420, 515, 545]
# 10
# s=210
# ts = [5, 30, 55, 80, 105, 130, 155, 180, 205, 230, 255, 280, 305, 330, 355, 380, 405, 430, 455, 480, 505, 530, 555, 580, 605]
# 25
# s=235
# ts = [60, 100, 185, 225, 310, 350, 435, 475, 560, 600]
# 10
# s=310
# ts = [70, 115, 195, 240, 320, 365, 445, 490, 570, 615]
# 10
# s=360
# ts = [10, 25, 135, 150, 260, 275, 385, 400, 510, 525]
# 10
# s=435
# ts = [90, 95, 215, 220, 340, 345, 465, 470, 590, 595]
# 10
# s=485
# ts = [75, 85, 200, 210, 325, 335, 450, 460, 575, 585]
# 10
# s=560
# ts = [65, 120, 190, 245, 315, 370, 440, 495, 565, 620]
# 10
# s=610
# ts = [0, 35, 125, 160, 250, 285, 375, 410, 500, 535]
# 10

# %%
num
# Out:
# 125

# %%
2*2 + 3*1 +3
# Out:
# 10

# %%
'''
Elliptic Curve defined by y^2*z + 3*x*y*z + 3*y*z^2 = x^3 + x^2*z + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 625 with Principal ideal (5) of Ring of integers modulo 625 as the maximal ideal
(4 : 0 : 1)
Ring of integers modulo 625
Principal ideal (5) of Ring of integers modulo 625
s=150
ts=[]

'''
R = Zmod(625)
num = 0
for i in range(125):
    x = R(4 + i*5)
    y = R(0)
    z = R(1)
    ts = [t for t in R if (y+t)^2*z + R(3)*x*(y+t)*z + 3*(y+t)*z^2 == x^3 + R(1)*x^2*z + 2*x*z^2 + R(2)*z^3]
    if len(ts) != 0:
        print("s=%s" %(5*i))
        print("ts = %s" %ts)
        print(len(ts))
    num = num + len(ts)
# Out:
# s=45
# ts = [5, 95, 130, 220, 255, 345, 380, 470, 505, 595]
# 10
# s=70
# ts = [60, 90, 185, 215, 310, 340, 435, 465, 560, 590]
# 10
# s=170
# ts = [105, 120, 230, 245, 355, 370, 480, 495, 605, 620]
# 10
# s=195
# ts = [40, 110, 165, 235, 290, 360, 415, 485, 540, 610]
# 10
# s=295
# ts = [20, 80, 145, 205, 270, 330, 395, 455, 520, 580]
# 10
# s=320
# ts = [35, 115, 160, 240, 285, 365, 410, 490, 535, 615]
# 10
# s=420
# ts = [45, 55, 170, 180, 295, 305, 420, 430, 545, 555]
# 10
# s=445
# ts = [65, 85, 190, 210, 315, 335, 440, 460, 565, 585]
# 10
# s=545
# ts = [30, 70, 155, 195, 280, 320, 405, 445, 530, 570]
# 10
# s=570
# ts = [10, 15, 135, 140, 260, 265, 385, 390, 510, 515]
# 10
# s=620
# ts = [0, 25, 50, 75, 100, 125, 150, 175, 200, 225, 250, 275, 300, 325, 350, 375, 400, 425, 450, 475, 500, 525, 550, 575, 600]
# 25

# %%
'''
Elliptic Curve defined by y^2*z + x*y*z + y*z^2 = x^3 + x^2*z + x*z^2 over local ring Ring of integers modulo 16 with Principal ideal (2) of Ring of integers modulo 16 as the maximal ideal
(1 : 1 : 1)
Ring of integers modulo 16
Principal ideal (2) of Ring of integers modulo 16
s=14
ts=[]
'''
R = Zmod(16)
num = 0
for i in range(8):
    x = R(1 + i*2)
    y = R(1)
    z = R(1)
    ts = [t for t in R if (y+t)^2*z + x*(y+t)*z + (y+t)*z^2 == x^3 + R(1)*x^2*z + x*z^2 ]
    if len(ts) != 0:
        print("s=%s" %(2*i))
        print("ts = %s" %ts)
        print(len(ts))
    num = num + len(ts)
# Out:
# s=0
# ts = [0, 4, 8, 12]
# 4
# s=4
# ts = [2, 6, 10, 14]
# 4

# %%
'''

Elliptic Curve defined by y^2*z + y*z^2 = x^3 + 2*x*z^2 + 2*z^3 over local ring Ring of integers modulo 81 with Principal ideal (3) of Ring of integers modulo 81 as the maximal ideal
(1 : 1 : 1)
Ring of integers modulo 81
Principal ideal (3) of Ring of integers modulo 81
s=0
ts=[]
'''
R = Zmod(81)
num = 0
for i in range(27):
    x = R(1 + i*3)
    y = R(1)
    z = R(1)
    ts = [t for t in R if (y+t)^2*z + 0*x*(y+t)*z + (y+t)*z^2 ==  x^3 + 2*x*z^2 + 2*z^3]
    if len(ts) != 0:
        print("s=%s" %(3*i))
        print("ts = %s" %ts)
        print(len(ts))
    num = num + len(ts)
# Out:
# s=21
# ts = [0, 24, 27, 51, 54, 78]
# 6
# s=48
# ts = [6, 18, 33, 45, 60, 72]
# 6
# s=57
# ts = [3, 12, 21, 30, 39, 48, 57, 66, 75]
# 9
# s=75
# ts = [9, 15, 36, 42, 63, 69]
# 6

# %%
'''
Elliptic Curve defined by y^2*z + x*y*z + 8*y*z^2 = x^3 + 2*x^2*z + 2*x*z^2 + 5*z^3 over local ring Ring of integers modulo 14641 with Principal ideal (11) of Ring of integers modulo 14641 as the maximal ideal
(1 : 1 : 1)
Ring of integers modulo 14641
Principal ideal (11) of Ring of integers modulo 14641
s=1210
ts=[]
'''
R = Zmod(14641)
num = 0
for i in range(11^3):
    x = R(1 + i*11)
    y = R(1)
    z = R(1)
    ts = [t for t in R if (y+t)^2*z + 1*x*(y+t)*z + 8*(y+t)*z^2 == x^3 + 2*x^2*z + 2*x*z^2 + 5*z^3]
    if len(ts) != 0:
        print("s=%s" %(11*i))
        print("ts = %s" %ts)
        print(len(ts))
    num = num + len(ts)
# Out:
# s=0
# ts = [0, 1320, 1331, 2651, 2662, 3982, 3993, 5313, 5324, 6644, 6655, 7975, 7986, 9306, 9317, 10637, 10648, 11968, 11979, 13299, 13310, 14630]
# 22
# s=363
# ts = [99, 858, 1430, 2189, 2761, 3520, 4092, 4851, 5423, 6182, 6754, 7513, 8085, 8844, 9416, 10175, 10747, 11506, 12078, 12837, 13409, 14168]
# 22
# s=847
# ts = [880, 924, 2211, 2255, 3542, 3586, 4873, 4917, 6204, 6248, 7535, 7579, 8866, 8910, 10197, 10241, 11528, 11572, 12859, 12903, 14190, 14234]
# 22
# s=968
# ts = [407, 1276, 1738, 2607, 3069, 3938, 4400, 5269, 5731, 6600, 7062, 7931, 8393, 9262, 9724, 10593, 11055, 11924, 12386, 13255, 13717, 14586]
# 22
# s=1089
# ts = [264, 1298, 1595, 2629, 2926, 3960, 4257, 5291, 5588, 6622, 6919, 7953, 8250, 9284, 9581, 10615, 10912, 11946, 12243, 13277, 13574, 14608]
# 22
# s=1331
# ts = [352, 968, 1683, 2299, 3014, 3630, 4345, 4961, 5676, 6292, 7007, 7623, 8338, 8954, 9669, 10285, 11000, 11616, 12331, 12947, 13662, 14278]
# 22
# s=1694
# ...

# %%
num
# Out:
# 1331
