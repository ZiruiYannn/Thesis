# %% [markdown]
# ## R.<r,X1,X2,Y1,Y2,Z1,Z2,a1,a2,a3,a4,a6,c1,c2> = PolynomialRing(Integers(),14)
# X1X2 = X1*X2
# X1Y2 = X1*Y2
# X1Z2 = X1*Z2
#
# X2Y1 = X2*Y1
# X2Z1 = X2*Z1
#
# Y1Z2 = Y1*Z2
# Y1Y2 = Y1*Y2
#
# Y2Z1 = Y2*Z1
#
# Z1Z2 = Z1*Z2
#
#
# a12 = a1*a1
# a1a2 = a1*a2
# a1a3 = a1*a3
# a1a4 = a1*a4
# a1a6 = a1*a6
#
# a2a3 = a2*a3
#
# a32 = a3*a3
# a3a4 = a3*a4
#
# X3 = (X1Y2 - X2Y1) * (Y1Z2 + Y2Z1) + (X1Z2 - X2Z1) * Y1Y2 + a1 * X1X2 * (Y1Z2 - Y2Z1) + \
# a1 * (X1Y2 - X2Y1) * (X1Z2 + X2Z1) - a2 * X1X2 * (X1Z2 - X2Z1) + a3 * (X1Y2 - X2Y1) * Z1Z2 + \
# a3 * (X1Z2 - X2Z1) * (Y1Z2 + Y2Z1) - a4 * (X1Z2 + X2Z1) *(X1Z2 - X2Z1) - 3*a6 * (X1Z2 - X2Z1) * Z1Z2
#
#
# Y3 = -3 * X1X2 * (X1Y2 - X2Y1) \
# - Y1Y2 * (Y1Z2 - Y2Z1) - 2*a1 * (X1Z2 - X2Z1) *  Y1Y2 \
# + (a12 + 3*a2) * X1X2 * (Y1Z2 - Y2Z1) \
# - (a12 + a2) * (X1Y2 + X2Y1) * (X1Z2 - X2Z1) \
# + (a1a2 - 3*a3) * X1X2 * (X1Z2 - X2Z1) \
# - (2*a1a3 + a4) * (X1Y2 - X2Y1) * Z1Z2 \
# + a4 * (X1Z2 + X2Z1) * (Y1Z2 - Y2Z1) \
# + (a1a4 - a2a3) * (X1Z2 + X2Z1) * (X1Z2 - X2Z1) \
# + (a32 + 3*a6) * (Y1Z2 - Y2Z1) * Z1Z2 \
# + (3 * a1a6 - a3a4) * (X1Z2 - X2Z1) * Z1Z2
#
# Z3 = 3 * X1X2 * (X1Z2 - X2Z1) - (Y1Z2 + Y2Z1) * (Y1Z2 - Y2Z1) \
# + a1 * (X1Y2 - X2Y1) * Z1Z2 - a1 * (X1Z2 - X2Z1) * (Y1Z2 + Y2Z1) \
# + a2 * (X1Z2 + X2Z1) * (X1Z2 - X2Z1) - a3 * (Y1Z2 - Y2Z1) * Z1Z2 \
# + a4 * (X1Z2 - X2Z1) * Z1Z2

# %%
g1 = X2*(a1*X1+a3*Z1+Y1)+X1Y2
g2 = Z2*(a1*X1+a3*Z1+Y1)+Z1*Y2
g3 = X1Z2 - X2Z1 
g4 = -X2*Y1 + X1*Y2
g5 = Y2*Z1 - Y1*Z2

# %%
H1 = X2*Y1*a1 + X1*Y2*a1 - X1*X2*a2 + 2*Y2*Z1*a3 + Y1*Z2*a3 - X2*Z1*a4 - X1*Z2*a4 - 3*Z1*Z2*a6 + 3*Y1*Y2
H2 = -Y2*Z1*a1 + X2*Z1*a2 + X1*Z2*a2 + Z1*Z2*a4 + 3*X1*X2
H3 = -X1*X2*a1^2 - X2*Z1*a1*a3 - X1*Z2*a1*a3 - Z1*Z2*a3^2 - X1*Y2*a1 - X1*X2*a2 - X2*Z1*a4 - X1*Z2*a4 - 3*Z1*Z2*a6 + Y1*Y2

# %%
X3 in Ideal(g2,g3)
# Out:
# True

# %%
X3 == g5*g1 + H1*g3
# Out:
# True

# %%
Z3 == g5*g2 + H2*g3
# Out:
# True

# %%
Y3(X1=X2,Y1=Y2,Z1=Z2)
# Out:
# 0

# %%
Y3 == -a1*g3*H1 - (a3*g3 + g4) *H2 + g5*H3
# Out:
# True

# %%
zf1 = R(zfx(X=X1))
zf2 = R(zfx(X=X2))

# %%
GX = X3(Y1=1,Y2=1,Z1=zf1,Z2=zf2)

# %%
#GX

# %%
GX(X1=X2)

# %%
g1 = X1-X2

# %%
g2 = (X1-X2)^2

# %%
g3 = (X1-X2)^3

# %%
G3 = X3(Y1=1,Y2=1,Z1=+1*X1^3,Z2=+1*X2^3)/Y3(Y1=1,Y2=1,Z1=+1*X1^3,Z2=+1*X2^3)

# %%
X3(Y1=1,Y2=1,Z1=+1*X1^3,Z2=+1*X2^3)
# Out:
# 3*X1^6*X2^4*a6 - 3*X1^4*X2^6*a6 + X1^6*X2^2*a4 - X1^2*X2^6*a4 - X1^6*X2*a3 + 2*X1^4*X2^3*a3 - 2*X1^3*X2^4*a3 + X1*X2^6*a3 + X1^4*X2^2*a2 - X1^2*X2^4*a2 - X1^3*X2^2*a1 + X1^2*X2^3*a1 + X1^4 - 2*X1^3*X2 + 2*X1*X2^3 - X2^4

# %%
X1^3 - 3*X1^2*X2 + 3*X1*X2^2 - X2^3 in Ideal(X1^3-X2^3)
# Out:
# False

# %%
G3/g1
# Out:
# X1^5*X2^4*a3*a4 + X1^4*X2^5*a3*a4 - 3*X1^5*X2^4*a1*a6 - 3*X1^4*X2^5*a1*a6 - X1^5*X2^3*a3^2 - X1^4*X2^4*a3^2 - X1^3*X2^5*a3^2 + X1^5*X2^2*a2*a3 + X1^4*X2^3*a2*a3 + X1^3*X2^4*a2*a3 + X1^2*X2^5*a2*a3 - X1^5*X2^2*a1*a4 - X1^4*X2^3*a1*a4 - X1^3*X2^4*a1*a4 - X1^2*X2^5*a1*a4 - 3*X1^5*X2^3*a6 - 3*X1^4*X2^4*a6 - 3*X1^3*X2^5*a6 - 2*X1^3*X2^3*a1*a3 - X1^3*X2^2*a1*a2 - X1^2*X2^3*a1*a2 - X1^5*X2*a4 - X1^4*X2^2*a4 - 3*X1^3*X2^3*a4 - X1^2*X2^4*a4 - X1*X2^5*a4 + X1^2*X2^2*a1^2 + 3*X1^3*X2^2*a3 + 3*X1^2*X2^3*a3 - 2*X1^3*X2*a2 - X1^2*X2^2*a2 - 2*X1*X2^3*a2 + 2*X1^2*X2*a1 + 2*X1*X2^2*a1 + X1^2 - 2*X1*X2 + X2^2

# %%
expand(Z3(Y1=1,Y2=1,Z1=+1*X1^3-1*a1*X1^4,Z2=+1*X2^3-1*a1*X2^4))
# Out:
# X1^8*X2^5*a1^3*a4 - X1^5*X2^8*a1^3*a4 - X1^8*X2^4*a1^3*a3 + X1^4*X2^8*a1^3*a3 - X1^8*X2^4*a1^2*a4 - 2*X1^7*X2^5*a1^2*a4 + 2*X1^5*X2^7*a1^2*a4 + X1^4*X2^8*a1^2*a4 + X1^8*X2^3*a1^2*a3 + 2*X1^7*X2^4*a1^2*a3 - 2*X1^4*X2^7*a1^2*a3 - X1^3*X2^8*a1^2*a3 - X1^8*X2^2*a1^2*a2 + X1^2*X2^8*a1^2*a2 + 2*X1^7*X2^4*a1*a4 + X1^6*X2^5*a1*a4 - X1^5*X2^6*a1*a4 - 2*X1^4*X2^7*a1*a4 + X1^8*X2*a1^3 - X1*X2^8*a1^3 - 2*X1^7*X2^3*a1*a3 - X1^6*X2^4*a1*a3 + X1^4*X2^6*a1*a3 + 2*X1^3*X2^7*a1*a3 + 2*X1^7*X2^2*a1*a2 - 2*X1^2*X2^7*a1*a2 - X1^6*X2^4*a4 + X1^4*X2^6*a4 + X1^8*a1^2 - 2*X1^7*X2*a1^2 + 2*X1*X2^7*a1^2 - X2^8*a1^2 + X1^6*X2^3*a3 - X1^3*X2^6*a3 - X1^6*X2^2*a2 + X1^2*X2^6*a2 - 2*X1^7*a1 + X1^6*X2*a1 + 3*X1^5*X2^2*a1 - 3*X1^2*X2^5*a1 - X1*X2^6*a1 + 2*X2^7*a1 + X1^6 - 3*X1^4*X2^2 + 3*X1^2*X2^4 - X2^6

# %%
Y34 = - X1^4*a1 + 2*X1^3*X2*a1 - 2*X1*X2^3*a1 + X2^4*a1 + X1^3 - 3*X1^2*X2 + 3*X1*X2^2 - X2^3

# %%
X34 =  X1^4 - 2*X1^3*X2 + 2*X1*X2^3 - X2^4

# %%
Y34%(X1-X2)
# Out:
# 0

# %%
Z12 = X1^3-1*a1*X1^4 - (X2^3-1*a1*X2^4)

# %%
Z12(X1=2,X2=1)
# Out:
# -15*a1 + 7

# %%
Z12(X1=3,X2=2)
# Out:
# -65*a1 + 19

# %%
X34(X1 = 2,X2=1)
# Out:
# 3

# %%
Y34(X1 = 2,X2=1)
# Out:
# -3*a1 + 1

# %%
X34(X1 = 3,X2=2)
# Out:
# 5

# %%
Y34(X1 = 3,X2=2)
# Out:
# -5*a1 + 1

# %%
G3
# Out:
# 3*X1^6*X2^4*a6 - 3*X1^4*X2^6*a6 + X1^6*X2^2*a4 - X1^2*X2^6*a4 - X1^6*X2*a3 + 2*X1^4*X2^3*a3 - 2*X1^3*X2^4*a3 + X1*X2^6*a3 + X1^4*X2^2*a2 - X1^2*X2^4*a2 - X1^3*X2^2*a1 + X1^2*X2^3*a1 + X1^4 - 2*X1^3*X2 + 2*X1*X2^3 - X2^4

# %%
X1X2 = X1*X2
X1Y2 = X1*Y2 
X1Z2 = X1*Z2

X2Y1 = X2*Y1
X2Z1 = X2*Z1

Y1Z2 = Y1*Z2
Y1Y2 = Y1*Y2

Y2Z1 = Y2*Z1

Z1Z2 = Z1*Z2


a12 = a1*a1
a13 = a1*a12
a1a2 = a1*a2
a1a3 = a1*a3
a1a4 = a1*a4
a1a6 = a1*a6


a22 = a2*a2
a2a3 = a2*a3
a2a4 = a2*a4 
a2a6 = a2*a6

a32 = a3*a3
a33 = a3*a32
a34 = a3*a33
a3a4 = a3*a4
a3a6 = a3*a6

a42 = a4*a4
a43 = a4*a42
a4a6 = a4*a6

a62 = a6*a6

X3 = Y1Y2 * (X1Y2 + X2Y1) + a1 * (2*X1Y2 + X2Y1) * X2Y1 + a12*X1X2*X2Y1\
- a2*X1X2 * (X1Y2 + X2Y1) - a1a2 * X1X2 * X1X2 + a3 * X2Y1 *(Y1Z2 + 2*Y2Z1)\
+ a1a3 * X1X2 * (Y1Z2 - Y2Z1) - a1a3 *(X1Y2 + X2Y1) * (X1Z2 - X2Z1)\
- a4 * X1X2 * (Y1Z2 + Y2Z1) - a4 * (X1Y2 + X2Y1) * (X1Z2 + X2Z1)\
- a12*a3 * X1X2 * X1Z2 - a1a4 * X1X2 * (2*X1Z2 + X2Z1)\
- a2a3 * X1X2 * X2Z1 - a32*X1Z2 * (2*Y2Z1 + Y1Z2)\
- 3* a6 * (X1Y2 + X2Y1) * Z1Z2\
- 3*a6 * (X1Z2 + X2Z1) * (Y1Z2 + Y2Z1) - a1*a32 * X1Z2 * (X1Z2 + 2*X2Z1)\
- 3*a1a6*X1Z2 * (X1Z2 + 2*X2Z1) + a3a4 * (-2*X1Z2 - X2Z1) * X2Z1\
- (a12*a6 - a1a3*a4 + a2*a32 + 4 * a2a6 - a42) * (Y1Z2 + Y2Z1) * Z1Z2\
- (a12*a1a6 - a12*a3a4 + a1a2*a32 + 4*a1a2*a6 - a1*a42) *X1Z2*Z1Z2\
- a33* (X1Z2 + X2Z1) * Z1Z2 - 3 * a3a6 * (X1Z2 + 2*X2Z1)*Z1Z2\
- (a1a3*a1a6 - a1a3*a3a4 + a2a3*a32 + 4*a2a3*a6 - a3*a42) * Z1Z2 * Z1Z2

Y3 = Y1Y2 * Y1Y2 + a1 * X2Y1* Y1Y2 + (a1a2 - 3*a3) * X1X2* X2Y1 \
+ a3 * Y1Y2 * Y1Z2 - (a22 - 3*a4) * X1X2 * X1X2 \
+ (a1a4 - a2a3) * (2 * X1Z2 + X2Z1) * X2Y1 \
+ (a1*a1a4 - 2*a1a2*a3 + 3*a32) * X1X2 * X1Z2 \
- (a2a4 - 9*a6) * X1X2 * (X1Z2 + X2Z1) \
+ (3*a1a6 - a3a4) * (X1Z2 + 2*X2Z1) * Y1Z2 \
+ (3*a1*a1a6 - 2*a1a3*a4 + a2*a32 + 3*a2a6 - a42) * X1Z2 * (X1Z2 + 2*X2Z1) \
- (3*a2a6 - a42) * (-2*X1Z2 - X2Z1) * X2Z1 \
+ (a13 * a6 - a12*a3a4 + a1a2*a32 - a1*a42 + 4*a1a2*a6 - a3*a32 - 3*a3a6) * Y1Z2 * Z1Z2 \
+ (a12*a12*a6 - a13 * a3a4 + 5*a12*a2a6 + a12*a2*a32 - a1a2*a3a4 - a1*a33 - 3*a1a3*a6\
-a12*a42 + a22*a32 - a2*a42 + 4*a22*a6 - a32*a4 - 3*a4a6) * X1Z2*Z1Z2 \
+ (a12*a2a6 - a1a2*a3a4 + 3*a1a3*a6 + a22*a32 - a2*a42 \
+ 4*a22*a6 - 2*a32*a4 - 3*a4a6) * X2Z1*Z1Z2 \
+ (a1*a1a3*a1a6 - a12*a32*a4 + a12*a4a6 + a1a2*a33 \
+ 4*a1a6*a2a3 - 2*a1a3*a42 + a2a3*a3a4 \
+ 4*a2*a4a6 - a34 - 6*a32*a6 - a43 - 9*a62) *Z1Z2 * Z1Z2\


Z3 = 3 * X1X2 * (X1Y2 + X2Y1) + Y1Y2 * (Y1Z2 + Y2Z1) + 3*a1*X1X2*X1X2 \
+ a1 * (2 * X1Y2 + X2Y1) * Y1Z2 + a12 * X1Z2 *(2*X2Y1 + X1Y2) \
+ a2 * X1X2 * (Y1Z2 + Y2Z1) \
+ a2 * (X1Y2 + X2Y1) * (X1Z2 + X2Z1) \
+ a13 * X1X2 * X1Z2 + a1a2 * X1X2 * (2*X1Z2 + X2Z1) \
+ 3*a3 * X1X2 * X2Z1 + a3 * Y1Z2 * (Y1Z2 + 2*Y2Z1) \
+ 2*a1a3 * X1Z2 * (Y1Z2 + Y2Z1) \
+ 2*a1a3*X2Y1*Z1Z2 + a4*(X1Y2 + X2Y1)* Z1Z2 \
+ a4* (X1Z2 + X2Z1) * (Y1Z2 + Y2Z1) \
+ (a12*a3 + a1a4) * X1Z2 * (X1Z2 + 2*X2Z1) + a2a3 * X2Z1 * (2*X1Z2 + X2Z1) \
+ a32 * Y1Z2*Z1Z2 + (a32 + 3*a6) * (Y1Z2 + Y2Z1) * Z1Z2 \
+ a1 * a32 * (2*X1Z2 + X2Z1) * Z1Z2 + 3*a1a6*X1Z2 * Z1Z2 \
+ a3a4 * (X1Z2 + 2*X2Z1) * Z1Z2 + (a33 + 3*a3a6) *Z1Z2*Z1Z2

# %%
X3(a3 = a3 - 2*r, a4 = a4 + r*a1, a6 = a6 + r*a3 - r*r)
# Out:
# 2*r*Z1^2*Z2^2*a2*a3^2 - X1*Z1*Z2^2*a1*a2*a3^2 - Z1^2*Z2^2*a2*a3^3 - 2*r*Z1^2*Z2^2*a1*a3*a4 + X1*Z1*Z2^2*a1^2*a3*a4 + Z1^2*Z2^2*a1*a3^2*a4 + 2*r*Z1^2*Z2^2*a1^2*a6 - X1*Z1*Z2^2*a1^3*a6 - Z1^2*Z2^2*a1^2*a3*a6 - 4*r^3*X2*Z1^2*Z2 + 2*r^3*X1*Z1*Z2^2 + 2*r^2*X2^2*Z1^2*a1 + 2*r^2*X1*X2*Z1*Z2*a1 - r^2*X1^2*Z2^2*a1 - r*X1*X2^2*Z1*a1^2 + 6*r^2*X2*Z1^2*Z2*a3 - 3*r^2*X1*Z1*Z2^2*a3 - r*X2^2*Z1^2*a1*a3 + r*X1^2*Z2^2*a1*a3 - X1^2*X2*Z2*a1^2*a3 + 3*r*X1*Z1*Z2^2*a3^2 - 2*X1*X2*Z1*Z2*a1*a3^2 - X1^2*Z2^2*a1*a3^2 - Y2*Z1^2*Z2*a2*a3^2 - Y1*Z1*Z2^2*a2*a3^2 - X2*Z1^2*Z2*a3^3 - X1*Z1*Z2^2*a3^3 + Y2*Z1^2*Z2*a1*a3*a4 + Y1*Z1*Z2^2*a1*a3*a4 - 2*r*Z1^2*Z2^2*a4^2 + X1*Z1*Z2^2*a1*a4^2 + Z1^2*Z2^2*a3*a4^2 - Y2*Z1^2*Z2*a1^2*a6 - Y1*Z1*Z2^2*a1^2*a6 + 8*r*Z1^2*Z2^2*a2*a6 - 4*X1*Z1*Z2^2*a1*a2*a6 - 4*Z1^2*Z2^2*a2*a3*a6 + 3*r^2*X2*Y2*Z1^2 + 6*r^2*X2*Y1*Z1*Z2 - 2*r^2*X1*Y2*Z1*Z2 - r^2*X1*Y1*Z2^2 - 3*r*X2^2*Y1*Z1*a1 - 2*r*X1*X2*Y2*Z1*a1 - 2*r*X1*X2*Y1*Z2*a1 + r*X1^2*Y2*Z2*a1 + X1*X2^2*Y1*a1^2 + 2*r*X1*X2^2*Z1*a2 - X1^2*X2^2
# ...

# %%
X3(Y1=0,Y2=0,Z1=1,Z2=1)
# Out:
# -X1^2*X2^2*a1*a2 - X1^2*X2*a1^2*a3 - X1*X2^2*a2*a3 - X1^2*a1*a3^2 - 2*X1*X2*a1*a3^2 - X1*a1*a2*a3^2 - 2*X1^2*X2*a1*a4 - X1*X2^2*a1*a4 + X1*a1^2*a3*a4 - X1*a1^3*a6 - X1*a3^3 - X2*a3^3 - a2*a3^3 - 2*X1*X2*a3*a4 - X2^2*a3*a4 + a1*a3^2*a4 + X1*a1*a4^2 - 3*X1^2*a1*a6 - 6*X1*X2*a1*a6 - 4*X1*a1*a2*a6 - a1^2*a3*a6 + a3*a4^2 - 3*X1*a3*a6 - 6*X2*a3*a6 - 4*a2*a3*a6

# %%
Y3(Y1=0,Y2=0,Z1=1,Z2=1)
# Out:
# -X1^2*X2^2*a2^2 - 2*X1^2*X2*a1*a2*a3 + X1*a1^2*a2*a3^2 + X1^2*X2*a1^2*a4 - X1*a1^3*a3*a4 + X1*a1^4*a6 + 3*X1^2*X2*a3^2 + X1^2*a2*a3^2 + 2*X1*X2*a2*a3^2 + X1*a2^2*a3^2 + X2*a2^2*a3^2 - X1*a1*a3^3 + a1*a2*a3^3 + 3*X1^2*X2^2*a4 - X1^2*X2*a2*a4 - X1*X2^2*a2*a4 - 2*X1^2*a1*a3*a4 - 4*X1*X2*a1*a3*a4 - X1*a1*a2*a3*a4 - X2*a1*a2*a3*a4 - a1^2*a3^2*a4 - X1*a1^2*a4^2 + 3*X1^2*a1^2*a6 + 6*X1*X2*a1^2*a6 + 5*X1*a1^2*a2*a6 + X2*a1^2*a2*a6 + a1^3*a3*a6 - a3^4 - X1*a3^2*a4 - 2*X2*a3^2*a4 + a2*a3^2*a4 - X1^2*a4^2 - 4*X1*X2*a4^2 - X2^2*a4^2 - X1*a2*a4^2 - X2*a2*a4^2 - 2*a1*a3*a4^2 + 9*X1^2*X2*a6 + 9*X1*X2^2*a6 + 3*X1^2*a2*a6 + 12*X1*X2*a2*a6 + 3*X2^2*a2*a6 + 4*X1*a2^2*a6 + 4*X2*a2^2*a6 - 3*X1*a1*a3*a6 + 3*X2*a1*a3*a6 + 4*a1*a2*a3*a6 + a1^2*a4*a6 - a4^3 - 6*a3^2*a6 - 3*X1*a4*a6 - 3*X2*a4*a6 + 4*a2*a4*a6 - 9*a6^2

# %%
Z3(Y1=0,Y2=0,Z1=1,Z2=1)
# Out:
# X1^2*X2*a1^3 + 3*X1^2*X2^2*a1 + 2*X1^2*X2*a1*a2 + X1*X2^2*a1*a2 + X1^2*a1^2*a3 + 2*X1*X2*a1^2*a3 + 3*X1*X2^2*a3 + 2*X1*X2*a2*a3 + X2^2*a2*a3 + 2*X1*a1*a3^2 + X2*a1*a3^2 + X1^2*a1*a4 + 2*X1*X2*a1*a4 + a3^3 + X1*a3*a4 + 2*X2*a3*a4 + 3*X1*a1*a6 + 3*a3*a6

# %%
X3(X1=2,X2=-1,Y1=3,Y2=0,Z1=1,Z2=1,a1=0,a3=0,a2=0,a4=0,a6=1)
# Out:
# 0

# %%
Y3(X1=2,X2=-1,Y1=3,Y2=0,Z1=1,Z2=1,a1=0,a3=0,a2=0,a4=0,a6=1)
# Out:
# -27

# %%
Z3(X1=2,X2=-1,Y1=3,Y2=0,Z1=1,Z2=1,a1=0,a3=0,a2=0,a4=0,a6=1)
# Out:
# 27

# %%
X3(X1=0,X2=2,Y1=4,Y2=3,Z1=1,Z2=1,a1=0,a3=0,a2=0,a4=0,a6=1)
# Out:
# 30

# %%
Y3(X1=0,X2=2,Y1=4,Y2=3,Z1=1,Z2=1,a1=0,a3=0,a2=0,a4=0,a6=1)
# Out:
# 135

# %%
Z3(X1=0,X2=2,Y1=4,Y2=3,Z1=1,Z2=1,a1=0,a3=0,a2=0,a4=0,a6=1)
# Out:
# 105

# %%
X3(X1=0,X2=2,Y1=0,Y2=4,Z1=1,Z2=1,a1=0,a3=-2,a2=0,a4=0,a6=0)
# Out:
# 16

# %%
Y3(X1=0,X2=2,Y1=0,Y2=4,Z1=1,Z2=1,a1=0,a3=-2,a2=0,a4=0,a6=0)
# Out:
# -16

# %%
Z3(X1=0,X2=2,Y1=0,Y2=4,Z1=1,Z2=1,a1=0,a3=-2,a2=0,a4=0,a6=0)
# Out:
# 8

# %%
X321 = X3
X322 = X3(Y2 = Y1,Y1 = Y2, X2 = X1,X1 = X2, Z1 = Z2, Z2=Z1)
Y321 = Y3
Y322 = Y3(Y2 = Y1,Y1 = Y2, X2 = X1,X1 = X2, Z1 = Z2, Z2=Z1)

# %%
diff = X312*Y321 - Y312*X321 
diff in Ideal(d1,d2)
# Out:
# True

# %%
X331 = c1*X311 + c2*X321
X332 = c1*X312 + c2*X322
Y331 = c1*Y311 + c2*Y321
Y332 = c1*Y312 + c2*Y322
d1 = Y1^2*Z1 + a1*X1*Y1*Z1 + a3*Y1*Z1^2 - X1^3 - a2*X1^2*Z1 - a4*X1*Z1^2 - a6*Z1^3
d2 = Y2^2*Z2 + a1*X2*Y2*Z2 + a3*Y2*Z2^2 - X2^3 - a2*X2^2*Z2 - a4*X2*Z2^2 - a6*Z2^3

diff = expand(X331 * Y332 - Y331 * X332)
diff in Ideal(d1,d2)
# Out:
# True

# %%
diff(a1=0,a3=0,a2=0) in Ideal(d1(a1=0,a3=0,a2=0),d2(a1=0,a3=0,a2=0))
# Out:
# False

# %%
d1(a1=0,a3=0,a2=0)
# Out:
# -X1*Z1^2*a4 - Z1^3*a6 - X1^3 + Y1^2*Z1

# %%
diff = Z3(Y2 = Y1,Y1 = Y2, X2 = X1,X1 = X2, Z1 = Z2, Z2=Z1) *X3 - Z3 * X3(Y2 = Y1,Y1 = Y2, X2 = X1,X1 = X2, Z1 = Z2, Z2=Z1)
d1 = Y1^2*Z1 + a1*X1*Y1*Z1 + a3*Y1*Z1^2 - X1^3 - a2*X1^2*Z1 - a4*X1*Z1^2 - a6*Z1^3
d2 = Y2^2*Z2 + a1*X2*Y2*Z2 + a3*Y2*Z2^2 - X2^3 - a2*X2^2*Z2 - a4*X2*Z2^2 - a6*Z2^3
diff in Ideal(d1,d2)
# Out:
# True

# %%
diff(a1=0,a3=0)
# Out:
# 0

# %%
Z3 in Ideal(g1,g2)
# Out:
# True

# %%
xpoly = X3(Y1=0,Y2=-a1*X2-a3,Z1=1,Z2=1)
xpoly
# Out:
# X1^2*X2*a2*a3 - X1*X2^2*a2*a3 - X1*a1*a2*a3^2 + X2*a1*a2*a3^2 - X1^2*X2*a1*a4 + X1*X2^2*a1*a4 + X1*a1^2*a3*a4 - X2*a1^2*a3*a4 - X1*a1^3*a6 + X2*a1^3*a6 + X1*a3^3 - X2*a3^3 + X1^2*a3*a4 - X2^2*a3*a4 + X1*a1*a4^2 - X2*a1*a4^2 - 3*X1^2*a1*a6 + 3*X2^2*a1*a6 - 4*X1*a1*a2*a6 + 4*X2*a1*a2*a6 + 3*X1*a3*a6 - 3*X2*a3*a6

# %%
xpoly.factor()
# Out:
# (-1) * (-X1 + X2) * (X1*X2*a2*a3 - a1*a2*a3^2 - X1*X2*a1*a4 + a1^2*a3*a4 - a1^3*a6 + a3^3 + X1*a3*a4 + X2*a3*a4 + a1*a4^2 - 3*X1*a1*a6 - 3*X2*a1*a6 - 4*a1*a2*a6 + 3*a3*a6)

# %%
ypoly = Y3(Y1=0,Y2=-a1*X2-a3,Z1=1,Z2=1)
ypoly
# Out:
# -X1^2*X2^2*a2^2 - 2*X1^2*X2*a1*a2*a3 + X1*a1^2*a2*a3^2 + X1^2*X2*a1^2*a4 - X1*a1^3*a3*a4 + X1*a1^4*a6 + 3*X1^2*X2*a3^2 + X1^2*a2*a3^2 + 2*X1*X2*a2*a3^2 + X1*a2^2*a3^2 + X2*a2^2*a3^2 - X1*a1*a3^3 + a1*a2*a3^3 + 3*X1^2*X2^2*a4 - X1^2*X2*a2*a4 - X1*X2^2*a2*a4 - 2*X1^2*a1*a3*a4 - 4*X1*X2*a1*a3*a4 - X1*a1*a2*a3*a4 - X2*a1*a2*a3*a4 - a1^2*a3^2*a4 - X1*a1^2*a4^2 + 3*X1^2*a1^2*a6 + 6*X1*X2*a1^2*a6 + 5*X1*a1^2*a2*a6 + X2*a1^2*a2*a6 + a1^3*a3*a6 - a3^4 - X1*a3^2*a4 - 2*X2*a3^2*a4 + a2*a3^2*a4 - X1^2*a4^2 - 4*X1*X2*a4^2 - X2^2*a4^2 - X1*a2*a4^2 - X2*a2*a4^2 - 2*a1*a3*a4^2 + 9*X1^2*X2*a6 + 9*X1*X2^2*a6 + 3*X1^2*a2*a6 + 12*X1*X2*a2*a6 + 3*X2^2*a2*a6 + 4*X1*a2^2*a6 + 4*X2*a2^2*a6 - 3*X1*a1*a3*a6 + 3*X2*a1*a3*a6 + 4*a1*a2*a3*a6 + a1^2*a4*a6 - a4^3 - 6*a3^2*a6 - 3*X1*a4*a6 - 3*X2*a4*a6 + 4*a2*a4*a6 - 9*a6^2

# %%
ypoly.factor()
# Out:
# (-1) * (X1^2*X2^2*a2^2 + 2*X1^2*X2*a1*a2*a3 - X1*a1^2*a2*a3^2 - X1^2*X2*a1^2*a4 + X1*a1^3*a3*a4 - X1*a1^4*a6 - 3*X1^2*X2*a3^2 - X1^2*a2*a3^2 - 2*X1*X2*a2*a3^2 - X1*a2^2*a3^2 - X2*a2^2*a3^2 + X1*a1*a3^3 - a1*a2*a3^3 - 3*X1^2*X2^2*a4 + X1^2*X2*a2*a4 + X1*X2^2*a2*a4 + 2*X1^2*a1*a3*a4 + 4*X1*X2*a1*a3*a4 + X1*a1*a2*a3*a4 + X2*a1*a2*a3*a4 + a1^2*a3^2*a4 + X1*a1^2*a4^2 - 3*X1^2*a1^2*a6 - 6*X1*X2*a1^2*a6 - 5*X1*a1^2*a2*a6 - X2*a1^2*a2*a6 - a1^3*a3*a6 + a3^4 + X1*a3^2*a4 + 2*X2*a3^2*a4 - a2*a3^2*a4 + X1^2*a4^2 + 4*X1*X2*a4^2 + X2^2*a4^2 + X1*a2*a4^2 + X2*a2*a4^2 + 2*a1*a3*a4^2 - 9*X1^2*X2*a6 - 9*X1*X2^2*a6 - 3*X1^2*a2*a6 - 12*X1*X2*a2*a6 - 3*X2^2*a2*a6 - 4*X1*a2^2*a6 - 4*X2*a2^2*a6 + 3*X1*a1*a3*a6 - 3*X2*a1*a3*a6 - 4*a1*a2*a3*a6 - a1^2*a4*a6 + a4^3 + 6*a3^2*a6 + 3*X1*a4*a6 + 3*X2*a4*a6 - 4*a2*a4*a6 + 9*a6^2)

# %%
zpoly = Z3(Y1=0,Y2=-a1*X2-a3,Z1=1,Z2=1)

# %%
zpoly.factor()
# Out:
# (-1) * (-X1 + X2) * (X1*X2*a1*a2 - 3*X1*X2*a3 - X1*a2*a3 - X2*a2*a3 + X1*a1*a4 + X2*a1*a4 - a3*a4 + 3*a1*a6)

# %%
X3(Z1=1,Z2=1,Y1=0,Y2=0,X2=X1)
# Out:
# -X1^4*a1*a2 - X1^3*a1^2*a3 - X1^3*a2*a3 - 3*X1^2*a1*a3^2 - X1*a1*a2*a3^2 - 3*X1^3*a1*a4 + X1*a1^2*a3*a4 - X1*a1^3*a6 - 2*X1*a3^3 - a2*a3^3 - 3*X1^2*a3*a4 + a1*a3^2*a4 + X1*a1*a4^2 - 9*X1^2*a1*a6 - 4*X1*a1*a2*a6 - a1^2*a3*a6 + a3*a4^2 - 9*X1*a3*a6 - 4*a2*a3*a6

# %%
Y3(Z1=1,Z2=1,Y1=0,Y2=0,X2=X1)
# Out:
# -X1^4*a2^2 - 2*X1^3*a1*a2*a3 + X1*a1^2*a2*a3^2 + X1^3*a1^2*a4 - X1*a1^3*a3*a4 + X1*a1^4*a6 + 3*X1^3*a3^2 + 3*X1^2*a2*a3^2 + 2*X1*a2^2*a3^2 - X1*a1*a3^3 + a1*a2*a3^3 + 3*X1^4*a4 - 2*X1^3*a2*a4 - 6*X1^2*a1*a3*a4 - 2*X1*a1*a2*a3*a4 - a1^2*a3^2*a4 - X1*a1^2*a4^2 + 9*X1^2*a1^2*a6 + 6*X1*a1^2*a2*a6 + a1^3*a3*a6 - a3^4 - 3*X1*a3^2*a4 + a2*a3^2*a4 - 6*X1^2*a4^2 - 2*X1*a2*a4^2 - 2*a1*a3*a4^2 + 18*X1^3*a6 + 18*X1^2*a2*a6 + 8*X1*a2^2*a6 + 4*a1*a2*a3*a6 + a1^2*a4*a6 - a4^3 - 6*a3^2*a6 - 6*X1*a4*a6 + 4*a2*a4*a6 - 9*a6^2

# %%
Z3(Z1=1,Z2=1,Y1=0,Y2=0,X2=X1)
# Out:
# X1^3*a1^3 + 3*X1^4*a1 + 3*X1^3*a1*a2 + 3*X1^2*a1^2*a3 + 3*X1^3*a3 + 3*X1^2*a2*a3 + 3*X1*a1*a3^2 + 3*X1^2*a1*a4 + a3^3 + 3*X1*a3*a4 + 3*X1*a1*a6 + 3*a3*a6

# %%
R.<X1,X2,Y1,Y2,Z1,Z2,a1,a2,a3,a4,a6> = PolynomialRing(Integers(),11) 

X1X2 = X1*X2
X1Y2 = X1*Y2 
X1Z2 = X1*Z2

X2Y1 = X2*Y1
X2Z1 = X2*Z1

Y1Z2 = Y1*Z2
Y1Y2 = Y1*Y2

Y2Z1 = Y2*Z1

Z1Z2 = Z1*Z2


a12 = a1*a1
a13 = a1*a12
a1a2 = a1*a2
a1a3 = a1*a3
a1a4 = a1*a4
a1a6 = a1*a6


a22 = a2*a2
a2a3 = a2*a3
a2a4 = a2*a4 
a2a6 = a2*a6

a32 = a3*a3
a33 = a3*a32
a34 = a3*a33
a3a4 = a3*a4
a3a6 = a3*a6

a42 = a4*a4
a43 = a4*a42
a4a6 = a4*a6

a62 = a6*a6

X3 = (X1Y2 + X2Y1)* (X1Y2 - X2Y1) + a1*X1X2 *(X1Y2 - X2Y1)\
- a3*X1X2* (Y1Z2 - Y2Z1) + a3* (X1Y2 + X2Y1)* (X1Z2 - X2Z1)\
+ (a1*a3 + a4)* X1X2 *(X1Z2 - X2Z1)\
+ (a32 + 3*a6)* (X1Z2 + X2Z1)* (X1Z2 - X2Z1)\
+ (a12*a6 - a1*a3*a4 + a2*a32 + 4*a2*a6 - a42)* (X1Z2 - X2Z1)* Z1Z2

Y3 = (X1Y2 - X2Y1)* Y1Y2 + a2*X1X2* (X1Y2 - X2Y1)\
+ 2*a3* (X1Z2 - X2Z1)* Y1Y2\
- (a1*a3 + 3*a4) *X1X2 *(Y1Z2 - Y2Z1)\
+ (a1*a3 + a4)* (X1Y2 + X2Y1) *(X1Z2 - X2Z1)\
- (a1a4 - a2a3)* X1X2* (X1Z2 - X2Z1)\
+ (2*a32 + 3*a6)* (X1Y2 - X2Y1)* Z1Z2\
- 3*a6* (X1Z2 + X2Z1)* (Y1Z2 - Y2Z1)\
- (3*a1a6 - a3a4)* (X1Z2 + X2Z1)* (X1Z2 - X2Z1)\
- (a12*a6 - a1*a3*a4 + a2*a32 + 4*a2*a6 - a42)* (Y1Z2 - Y2Z1)* Z1Z2\
- (a13*a6 - a12*a3*a4 + a1*a2*a32 + 4*a1*a2*a6\
-a1*a42 - a33 - 3*a3*a6)* (X1Z2 - X2Z1)* Z1Z2


Z3 = - (X1Y2 + X2Y1)* (Y1Z2 - Y2Z1) - (X1Z2 - X2Z1)* Y1Y2\
- a1*X1X2* (Y1Z2 - Y2Z1) - a1* (X1Y2 + X2Y1)* (X1Z2 - X2Z1)\
- (a12 + a2)* X1X2* (X1Z2 - X2Z1) - a3* (X1Y2 - X2Y1)* Z1Z2\
- a3* (X1Z2 + X2Z1)* (Y1Z2 - Y2Z1)\
- (a1a3 + a4)* (X1Z2 + X2Z1)* (X1Z2 - X2Z1)\
- (a32 + 3*a6)* (X1Z2 - X2Z1)* Z1Z2

# %%
X3(X1=2,X2=-1,Y1=3,Y2=0,Z1=1,Z2=1,a1=0,a3=0,a2=0,a4=0,a6=1)
# Out:
# 0

# %%
Y3(X1=2,X2=-1,Y1=3,Y2=0,Z1=1,Z2=1,a1=0,a3=0,a2=0,a4=0,a6=1)
# Out:
# 0

# %%
Z3(X1=2,X2=-1,Y1=3,Y2=0,Z1=1,Z2=1,a1=0,a3=0,a2=0,a4=0,a6=1)
# Out:
# 0

# %%
Z3(Y2 = Y1,Y1 = Y2, X2 = X1,X1 = X2, Z1 = Z2, Z2=Z1) *X3 == Z3 * X3(Y2 = Y1,Y1 = Y2, X2 = X1,X1 = X2, Z1 = Z2, Z2=Z1)
# Out:
# True

# %%
H1 =Z1*Z2*a2*a3^2 - Z1*Z2*a1*a3*a4 + Z1*Z2*a1^2*a6 + X1*X2*a1*a3 + X2*Z1*a3^2 + X1*Z2*a3^2 - Z1*Z2*a4^2 + 4*Z1*Z2*a2*a6 + X1*Y2*a3 + X1*X2*a4 + 3*X2*Z1*a6 + 3*X1*Z2*a6

# %%
H2 = -X1*X2*a1^2 - X2*Z1*a1*a3 - X1*Z2*a1*a3 - Z1*Z2*a3^2 - X2*Y1*a1 - 2*X1*Y2*a1 - X1*X2*a2 - Y2*Z1*a3 - Y1*Z2*a3 - X2*Z1*a4 - X1*Z2*a4 - 3*Z1*Z2*a6 - 3*Y1*Y2

# %%
H3 = X1*X2*a2 - Y2*Z1*a3 + X2*Z1*a4 + X1*Z2*a4 + 3*Z1*Z2*a6 + Y1*Y2

# %%
X3 == g1*g4 + g3*H1
# Out:
# True

# %%
Z3 == g2*g4 + g3*H2
# Out:
# True

# %%
(-a1*g3 + g5)* H1 -a3*g3*H2 +g4*H3 == Y3
# Out:
# True

# %%
Z3(X1=X2, Y1=1,Y2=1,Z1=Z2)
# Out:
# 0

# %%
X3 in Ideal(g1,g3)
# Out:
# True

# %%
Z3 in Ideal(g1,g3)
# Out:
# True

# %%
X3(X1=X2,Y1=Y2,Z1=Z2)
# Out:
# 0

# %%
Z3 in Ideal(g3,g4,g5)
# Out:
# True

# %%
I13 = Ideal(g1,g3)

# %%
I345 = Ideal(g3,g4,g5)

# %%
J = I13.intersection(I345)

# %%
g1*g3, g1*g4, g1*g5, g3*g3,g3*g4

# %%
X3 in J
# Out:
# True

# %%
Z3 in J
# Out:
# True

# %%
Jgen = J.gens()

# %%
Jgen[0].factor()
# Out:
# X2*Z1 - X1*Z2

# %%
Jgen[1].factor()
# Out:
# X1*X2*Y1*Z2*a1 - X1^2*Y2*Z2*a1 - X1*Y2*Z1*Z2*a3 + X1*Y1*Z2^2*a3 - X1*Y2^2*Z1 + X2*Y1^2*Z2

# %%
Jgen[2].factor()
# Out:
# (-1) * (-X2*Y1 + X1*Y2) * (X1*X2*a1 + X1*Z2*a3 + X2*Y1 + X1*Y2)

# %%
Jgen[3].factor()
# Out:
# (-1) * X1 * (-Y2*Z1 + Y1*Z2) * (X1*Z2*a1 + Z1*Z2*a3 + Y2*Z1 + Y1*Z2)

# %%
I3 = Ideal(g3,g1*g4,g1*g5)

# %%
I3.gens()
# Out:
# [-X2*Z1 + X1*Z2, -X1*X2^2*Y1*a1 + X1^2*X2*Y2*a1 - X2^2*Y1*Z1*a3 + X1*X2*Y2*Z1*a3 - X2^2*Y1^2 + X1^2*Y2^2, X1*X2*Y2*Z1*a1 - X1*X2*Y1*Z2*a1 + X2*Y2*Z1^2*a3 - X2*Y1*Z1*Z2*a3 + X2*Y1*Y2*Z1 + X1*Y2^2*Z1 - X2*Y1^2*Z2 - X1*Y1*Y2*Z2]

# %%
J.gens()
# Out:
# [X2*Z1 - X1*Z2, X1*X2*Y1*Z2*a1 - X1^2*Y2*Z2*a1 - X1*Y2*Z1*Z2*a3 + X1*Y1*Z2^2*a3 - X1*Y2^2*Z1 + X2*Y1^2*Z2, X1*X2^2*Y1*a1 - X1^2*X2*Y2*a1 + X1*X2*Y1*Z2*a3 - X1^2*Y2*Z2*a3 + X2^2*Y1^2 - X1^2*Y2^2, X1^2*Y2*Z1*Z2*a1 - X1^2*Y1*Z2^2*a1 + X1*Y2*Z1^2*Z2*a3 - X1*Y1*Z1*Z2^2*a3 + X1*Y2^2*Z1^2 - X1*Y1^2*Z2^2]

# %%
I3 == J
# Out:
# True

# %%
J >= I3
# Out:
# True

# %%
g1*g4 in J
# Out:
# True

# %%
g1*g5 in J
# Out:
# True

# %%
g3 in J
# Out:
# True

# %%
Y3 in Ideal(g3,g4,g5)
# Out:
# True

# %%
Y3 in J
# Out:
# False

# %%
g3 in Ideal(g4,g5)
# Out:
# False

# %%
X3.lift(I3)
# Out:
# [Z1*Z2*a2*a3^2 - Z1*Z2*a1*a3*a4 + Z1*Z2*a1^2*a6 + X1*X2*a1*a3 + X2*Z1*a3^2 + X1*Z2*a3^2 - Z1*Z2*a4^2 + 4*Z1*Z2*a2*a6 + X1*Y2*a3 + X1*X2*a4 + 3*X2*Z1*a6 + 3*X1*Z2*a6, 1, 0]

# %%
f = Z1*Z2*a2*a3^2 - Z1*Z2*a1*a3*a4 + Z1*Z2*a1^2*a6 + X1*X2*a1*a3 + X2*Z1*a3^2 + X1*Z2*a3^2 - Z1*Z2*a4^2 + 4*Z1*Z2*a2*a6 + X1*Y2*a3 + X1*X2*a4 + 3*X2*Z1*a6 + 3*X1*Z2*a6

# %%
f.factor()
# Out:
# Z1*Z2*a2*a3^2 - Z1*Z2*a1*a3*a4 + Z1*Z2*a1^2*a6 + X1*X2*a1*a3 + X2*Z1*a3^2 + X1*Z2*a3^2 - Z1*Z2*a4^2 + 4*Z1*Z2*a2*a6 + X1*Y2*a3 + X1*X2*a4 + 3*X2*Z1*a6 + 3*X1*Z2*a6

# %%
Z3.lift(I3)
# Out:
# [-X1*X2*a1^2 - X2*Z1*a1*a3 - X1*Z2*a1*a3 - Z1*Z2*a3^2 - X2*Y1*a1 - X1*Y2*a1 - X1*X2*a2 - Y1*Z2*a3 - X2*Z1*a4 - X1*Z2*a4 - 3*Z1*Z2*a6 - Y1*Y2, 0, 1]

# %%
-X1*X2*a1^2 - X2*Z1*a1*a3 - X1*Z2*a1*a3 - Z1*Z2*a3^2 - X2*Y1*a1 - X1*Y2*a1 - X1*X2*a2 - Y1*Z2*a3 - X2*Z1*a4 - X1*Z2*a4 - 3*Z1*Z2*a6 - Y1*Y2
# Out:
# -X1*X2*a1^2 - X2*Z1*a1*a3 - X1*Z2*a1*a3 - Z1*Z2*a3^2 - X2*Y1*a1 - X1*Y2*a1 - X1*X2*a2 - Y1*Z2*a3 - X2*Z1*a4 - X1*Z2*a4 - 3*Z1*Z2*a6 - Y1*Y2

# %%
f.factor()
# Out:
# (-1) * (X1*X2*a1^2 + X2*Z1*a1*a3 + X1*Z2*a1*a3 + Z1*Z2*a3^2 + X2*Y1*a1 + X1*Y2*a1 + Y1*Z2*a3 + X2*Z1*a4 + X1*Z2*a4)

# %%
I3.gens()
# Out:
# [-X2*Z1 + X1*Z2, -X1*X2^2*Y1*a1 + X1^2*X2*Y2*a1 - X2^2*Y1*Z1*a3 + X1*X2*Y2*Z1*a3 - X2^2*Y1^2 + X1^2*Y2^2, X1*X2*Y2*Z1*a1 - X1*X2*Y1*Z2*a1 + X2*Y2*Z1^2*a3 - X2*Y1*Z1*Z2*a3 + X2*Y1*Y2*Z1 + X1*Y2^2*Z1 - X2*Y1^2*Z2 - X1*Y1*Y2*Z2]

# %%
X1*X2*Y2*Z1*a1 - X1*X2*Y1*Z2*a1 + X2*Y2*Z1^2*a3 - X2*Y1*Z1*Z2*a3 + X2*Y1*Y2*Z1 + X1*Y2^2*Z1 - X2*Y1^2*Z2 - X1*Y1*Y2*Z2 == g2*g4
# Out:
# False

# %%
-X1*X2*a1^2 - X2*Z1*a1*a3 - X1*Z2*a1*a3 - Z1*Z2*a3^2 - X2*Y1*a1 - X1*Y2*a1 - X1*X2*a2 - Y1*Z2*a3 - X2*Z1*a4 - X1*Z2*a4 - 3*Z1*Z2*a6 - Y1*Y2 == -X1*X2*a1^2 - X2*Z1*a1*a3 - X1*Z2*a1*a3 - Z1*Z2*a3^2 - X2*Y1*a1 - 2*X1*Y2*a1 - X1*X2*a2 - Y2*Z1*a3 - Y1*Z2*a3 - X2*Z1*a4 - X1*Z2*a4 - 3*Z1*Z2*a6 - 3*Y1*Y2
# Out:
# False

# %%
X3 in I3
# Out:
# True

# %%
Z3 in I3
# Out:
# True

# %%
X3.lift(I3)
# Out:
# [Z1*Z2*a2*a3^2 - Z1*Z2*a1*a3*a4 + Z1*Z2*a1^2*a6 + X1*X2*a1*a3 + X2*Z1*a3^2 + X1*Z2*a3^2 - Z1*Z2*a4^2 + 4*Z1*Z2*a2*a6 + X1*Y2*a3 + X1*X2*a4 + 3*X2*Z1*a6 + 3*X1*Z2*a6, 1, 0]

# %%
H11 = Z1*Z2*a2*a3^2 - Z1*Z2*a1*a3*a4 + Z1*Z2*a1^2*a6 + X1*X2*a1*a3 + X2*Z1*a3^2 + X1*Z2*a3^2 - Z1*Z2*a4^2 + 4*Z1*Z2*a2*a6 + X1*Y2*a3 + X1*X2*a4 + 3*X2*Z1*a6 + 3*X1*Z2*a6

# %%
Z3.lift(I3)
# Out:
# [-X1*X2*a1^2 - X2*Z1*a1*a3 - X1*Z2*a1*a3 - Z1*Z2*a3^2 - X2*Y1*a1 - X1*Y2*a1 - X1*X2*a2 - Y1*Z2*a3 - X2*Z1*a4 - X1*Z2*a4 - 3*Z1*Z2*a6 - Y1*Y2, 0, 1]

# %%
H12 = -X1*X2*a1^2 - X2*Z1*a1*a3 - X1*Z2*a1*a3 - Z1*Z2*a3^2 - X2*Y1*a1 - X1*Y2*a1 - X1*X2*a2 - Y1*Z2*a3 - X2*Z1*a4 - X1*Z2*a4 - 3*Z1*Z2*a6 - Y1*Y2

# %%
Y3 in Ideal(H11,H12,g1,g2)
# Out:
# True

# %%
HY = Y3.lift(Ideal(H11,H12,g1,g2))

# %%
HY[0]
# Out:
# X2*Z1*a1 + Z1*Z2*a3 + 2*Y2*Z1

# %%
HY[1]
# Out:
# X2*Z1*a3 - X1*Z2*a3 + X2*Y1 - X1*Y2

# %%
HY[2]
# Out:
# -X1*Z2*a1*a3 - Z1*Z2*a3^2 + X2*Y1*a1 - X1*Y2*a1 - 2*Y2*Z1*a3

# %%
HY[3]
# Out:
# -Z1*Z2*a2*a3^2 + Z1*Z2*a1*a3*a4 - Z1*Z2*a1^2*a6 - X1*Z2*a3^2 + Z1*Z2*a4^2 - 4*Z1*Z2*a2*a6 + X2*Y1*a3 - X1*X2*a4 - 3*X2*Z1*a6 - 3*X1*Z2*a6

# %%
HY[2] in Ideal(g2,g3,g4,g5)
# Out:
# True

# %%
HY[2].lift(Ideal(g2,g4,g5))
# Out:
# [-a3, -a1, -a3]

# %%
HY[1] in Ideal(g2,g3,g4,g5)
# Out:
# True

# %%
HY[1].lift(Ideal(g3,g4))
# Out:
# [-a3, -1]

# %%
HY[0] in Ideal(g2,g3,g4,g5)
# Out:
# True

# %%
HY[0].lift(Ideal(g2,g3,g5))
# Out:
# [1, -a1, 1]

# %%
HY[3] in Ideal(g1,g2,g3,g4,g5,Z1Z2,X1X2)
# Out:
# False

# %%
X3 in JJ
# Out:
# True

# %%
Z3 in JJ
# Out:
# True

# %%
JJ = Ideal(g3,g4).intersection(Ideal(g3,g1))

# %%
X3.lift(JJ)
# Out:
# [-Z1*Z2*a2*a3^2 + Z1*Z2*a1*a3*a4 - Z1*Z2*a1^2*a6 - X1*X2*a1*a3 - X2*Z1*a3^2 - X1*Z2*a3^2 + Z1*Z2*a4^2 - 4*Z1*Z2*a2*a6 - X2*Y1*a3 - X1*X2*a4 - 3*X2*Z1*a6 - 3*X1*Z2*a6, 0, -1, 0]

# %%
Z3.lift(JJ)
# Out:
# [X1*X2*a1^2 + X2*Z1*a1*a3 + X1*Z2*a1*a3 + Z1*Z2*a3^2 + X2*Y1*a1 + 2*X1*Y2*a1 + X1*X2*a2 + Y2*Z1*a3 + X2*Z1*a4 + X1*Z2*a4 + 3*Z1*Z2*a6 + 2*Y1*Y2, -1, 0, 0]

# %%
JJ == Ideal(g3,g1*g4,g2*g4)
# Out:
# True

# %%
JJ == Ideal(g3,g1*g4,g1*g5)
# Out:
# True

# %%
JJ.gens()
# Out:
# [X2*Z1 - X1*Z2, X1*X2*Y1*Z2*a1 - X1^2*Y2*Z2*a1 - X1*Y2*Z1*Z2*a3 + X1*Y1*Z2^2*a3 - X1*Y2^2*Z1 + X2*Y1^2*Z2, X1*X2^2*Y1*a1 - X1^2*X2*Y2*a1 + X1*X2*Y1*Z2*a3 - X1^2*Y2*Z2*a3 + X2^2*Y1^2 - X1^2*Y2^2, X1^2*Y2*Z1*Z2*a1 - X1^2*Y1*Z2^2*a1 + X1*Y2*Z1^2*Z2*a3 - X1*Y1*Z1*Z2^2*a3 + X1*Y2^2*Z1^2 - X1*Y1^2*Z2^2]

# %%
Z3.lift(Ideal(g3,g1*g4,g2*g4))
# Out:
# [-X1*X2*a1^2 - X2*Z1*a1*a3 - X1*Z2*a1*a3 - Z1*Z2*a3^2 - X2*Y1*a1 - 2*X1*Y2*a1 - X1*X2*a2 - Y2*Z1*a3 - Y1*Z2*a3 - X2*Z1*a4 - X1*Z2*a4 - 3*Z1*Z2*a6 - 3*Y1*Y2, 0, 1]

# %%
Z3.lift(Ideal(g3,g1*g4,g1*g5))
# Out:
# [-X1*X2*a1^2 - X2*Z1*a1*a3 - X1*Z2*a1*a3 - Z1*Z2*a3^2 - X2*Y1*a1 - X1*Y2*a1 - X1*X2*a2 - Y1*Z2*a3 - X2*Z1*a4 - X1*Z2*a4 - 3*Z1*Z2*a6 - Y1*Y2, 0, 1]

# %%
g24 = g2*g4

# %%
g24.lift(Ideal(g3,g1*g5))
# Out:
# [X1*Y2*a1 + Y2*Z1*a3 + 2*Y1*Y2, 1]

# %%
(X1*Y2*a1 + Y2*Z1*a3 + 2*Y1*Y2) * g3 + g1*g5 == g2*g4
# Out:
# True

# %%
g1 = X2*(a1*X1+a3*Z1+Y1)+X1Y2
g2 = Z2*(a1*X1+a3*Z1+Y1)+Z1*Y2
g3 = X1Z2 - X2Z1 
g4 = -X2*Y1 + X1*Y2
g5 = Y2*Z1 - Y1*Z2

# %%
Y2*(a1*X1+a3*Z1+Y1)+Y1Y2 == X1*Y2*a1 + Y2*Z1*a3 + 2*Y1*Y2
# Out:
# True

# %%
g6 = Y2*(a1*X1+a3*Z1+Y1)+Y1Y2

# %%
X3 in Ideal(g1*g4,g3,g6)
# Out:
# True

# %%
Z3 in Ideal(g1*g4,g3,g6)
# Out:
# False

# %%
X3 == g1*g4 + g3*H8
Z3 == g2*g4 + g3*H9
Y3 == (-a1*g3 + g5)* H8 -a3*g3*H9 +g4*H10 == (-a1*g3 + g5) H8 + (-a3*g3 + g4) * H10 + H11

# %%
H8 =Z1*Z2*a2*a3^2 - Z1*Z2*a1*a3*a4 + Z1*Z2*a1^2*a6 + X1*X2*a1*a3 + X2*Z1*a3^2 + X1*Z2*a3^2 - Z1*Z2*a4^2 + 4*Z1*Z2*a2*a6 + X1*Y2*a3 + X1*X2*a4 + 3*X2*Z1*a6 + 3*X1*Z2*a6
H9 = -X1*X2*a1^2 - X2*Z1*a1*a3 - X1*Z2*a1*a3 - Z1*Z2*a3^2 - X2*Y1*a1 - 2*X1*Y2*a1 - X1*X2*a2 - Y2*Z1*a3 - Y1*Z2*a3 - X2*Z1*a4 - X1*Z2*a4 - 3*Z1*Z2*a6 - 3*Y1*Y2
H10 = X1*X2*a2 - Y2*Z1*a3 + X2*Z1*a4 + X1*Z2*a4 + 3*Z1*Z2*a6 + Y1*Y2

# %%
H9
# Out:
# -X1*X2*a1^2 - X2*Z1*a1*a3 - X1*Z2*a1*a3 - Z1*Z2*a3^2 - X2*Y1*a1 - 2*X1*Y2*a1 - X1*X2*a2 - Y2*Z1*a3 - Y1*Z2*a3 - X2*Z1*a4 - X1*Z2*a4 - 3*Z1*Z2*a6 - 3*Y1*Y2

# %%
H10
# Out:
# X1*X2*a2 - Y2*Z1*a3 + X2*Z1*a4 + X1*Z2*a4 + 3*Z1*Z2*a6 + Y1*Y2

# %%
H9 + H10
# Out:
# -X1*X2*a1^2 - X2*Z1*a1*a3 - X1*Z2*a1*a3 - Z1*Z2*a3^2 - X2*Y1*a1 - 2*X1*Y2*a1 - 2*Y2*Z1*a3 - Y1*Z2*a3 - 2*Y1*Y2

# %%
- X2*Z1*a4 - X1*Z2*a4 - 3*Z1*Z2*a6 - 3*Y1*Y2 + X2*Z1*a4 + X1*Z2*a4 + 3*Z1*Z2*a6 + Y1*Y2
# Out:
# -2*Y1*Y2

# %%
X3 in Ideal(-a3*g3 + g4,g3)
# Out:
# True

# %%
Z3 in Ideal(-a1*g3 + g5,g3)
# Out:
# True

# %%
HX = X3.lift(Ideal(-a3*g3 + g4,g3))

# %%
HZ = Z3.lift(Ideal(-a1*g3 + g5,g3))

# %%
H1 = HX[0]
H2 = HX[1]
H3 = HZ[0]
H4 = HZ[1]

# %%
Y3 in Ideal(H1,H2,H3,H4,g5)
# Out:
# True

# %%
HY = Y3.lift(Ideal(H1,H2,H3,H4,g5))

# %%
HY[0] in Ideal(H1,H2,H3,H4,g4,g5)
# Out:
# True

# %%
HY[1] in Ideal(H1,H2,H3,H4,g3,g5)
# Out:
# True

# %%
HY[2] in Ideal(g4,g5)
# Out:
# False

# %%
HY[3] in Ideal(g4,g5)
# Out:
# True

# %%
expand((1+a1*X)*(1-a1*X-a1^2*x^2))
# Out:
# -X*a1^3*x^2 - X^2*a1^2 - a1^2*x^2 + 1
