# %%
var('X,Y,Z,U,V,W')
# Out:
# (X, Y, Z, U, V, W)

# %%
equ = X^3 + Y^3 - 2*Z^3

# %%
A = Matrix([[1 , 1,  -2],[1 ,-1 , 0],[   1 ,  1  , 0]])

# %%
A^-1
# Out:
# [   0  1/2  1/2]
# [   0 -1/2  1/2]
# [-1/2    0  1/2]

# %%
expand( equ( X=(W+V)/2,Y=(W-V)/2,Z=(-U+W)/2  ) )
# Out:
# 1/4*U^3 - 3/4*U^2*W + 3/4*V^2*W + 3/4*U*W^2

# %%
9*25
# Out:
# 225
